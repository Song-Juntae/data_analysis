# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import glob
upics = glob.glob('/home/sjt/space/github/data_analysis/data/cell_images/Uninfected/*.png')
apics = glob.glob('/home/sjt/space/github/data_analysis/data/cell_images/Parasitized/*.png')
len(upics), upics[0], len(apics), apics[0]
# Out:
# (13779,
#  '/home/sjt/space/github/data_analysis/data/cell_images/Uninfected/C213ThinF_IMG_20151106_112422_cell_168.png',
#  13779,
#  '/home/sjt/space/github/data_analysis/data/cell_images/Parasitized/C99P60ThinF_IMG_20150918_141351_cell_127.png')

# %%
# upics 
upics_0 = upics[0]
upics_0_img = plt.imread(upics_0)
plt.imshow(upics_0_img)
